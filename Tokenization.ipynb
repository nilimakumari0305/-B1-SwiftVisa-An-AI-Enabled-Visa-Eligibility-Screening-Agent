# %%
# !pip install torch torchvision torchaudio
# Out:
# Requirement already satisfied: torch in c:\users\asus\anaconda\lib\site-packages (2.8.0)
# Requirement already satisfied: torchvision in c:\users\asus\anaconda\lib\site-packages (0.23.0)
# Requirement already satisfied: torchaudio in c:\users\asus\anaconda\lib\site-packages (2.8.0)
# Requirement already satisfied: filelock in c:\users\asus\anaconda\lib\site-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\asus\anaconda\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\asus\anaconda\lib\site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in c:\users\asus\anaconda\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\asus\anaconda\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\asus\anaconda\lib\site-packages (from torch) (2025.3.2)
# Requirement already satisfied: setuptools in c:\users\asus\anaconda\lib\site-packages (from torch) (72.1.0)
# Requirement already satisfied: numpy in c:\users\asus\appdata\roaming\python\python313\site-packages (from torchvision) (2.2.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\asus\anaconda\lib\site-packages (from torchvision) (11.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\asus\anaconda\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asus\anaconda\lib\site-packages (from jinja2->torch) (3.0.2)

# %%
# !pip install tokenizers
# Out:
# Requirement already satisfied: tokenizers in c:\users\asus\anaconda\lib\site-packages (0.22.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\users\asus\anaconda\lib\site-packages (from tokenizers) (0.35.3)
# Requirement already satisfied: filelock in c:\users\asus\anaconda\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\asus\anaconda\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in c:\users\asus\anaconda\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\asus\anaconda\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (6.0.2)
# Requirement already satisfied: requests in c:\users\asus\anaconda\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\asus\anaconda\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\asus\anaconda\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (4.12.2)
# Requirement already satisfied: colorama in c:\users\asus\anaconda\lib\site-packages (from tqdm>=4.42.1->huggingface-hub<2.0,>=0.16.4->tokenizers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\asus\anaconda\lib\site-packages (from requests->huggingface-hub<2.0,>=0.16.4->tokenizers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\anaconda\lib\site-packages (from requests->huggingface-hub<2.0,>=0.16.4->tokenizers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\anaconda\lib\site-packages (from requests->huggingface-hub<2.0,>=0.16.4->tokenizers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\anaconda\lib\site-packages (from requests->huggingface-hub<2.0,>=0.16.4->tokenizers) (2025.7.14)

# %%
import torch 
import torch.nn as nn
from tokenizers import Tokenizer , models, trainers, pre_tokenizers
from tokenizers.pre_tokenizers import Whitespace
import torch.optim as optim
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
corpus = [ 
    " apple mango fruit",
    "car bus vehicle",
    "apple car mango bus",
    "fruit vehicle"
]

# %%
with open("corpus_1.txt", "w", encoding = "utf-8") as f:
    for line in corpus:
        f.write(line + '\n')

# %%
#Train BPE Tokenizer
tokenizer = Tokenizer(models.BPE())
tokenizer.pre_tokenizers = Whitespace()
trainer = trainers.BpeTrainer(vocab_size = 100 , show_progress = True, special_tokens = ["[UNK]", "[CLS]", "[SEP]"])
tokenizer.train(["corpus_1.txt"], trainer)

output  = tokenizer.encode("apple car mango")
print("TOKENS : ", output.tokens)
print("TOKEN_ids : ", output.ids)
# Out:
# TOKENS :  ['apple car', ' mango']
# TOKEN_ids :  [55, 48]

# %%
# Embeddings
vocab_size = tokenizer.get_vocab_size()
embed_dim = 8 
embedding = nn.Embedding(vocab_size, embed_dim)
token_ids = torch.tensor(output.ids)
embeds = embedding(token_ids)

print("Embeddding Shape :", embeds.shape)
print('Sample Embeddibngs:\n', embeds)
# Out:
# Embeddding Shape : torch.Size([2, 8])
# Sample Embeddibngs:
#  tensor([[-1.5385, -0.3124, -0.3426, -0.0891, -0.1710, -0.7955, -1.7792,  0.3229],
#         [ 0.4457,  1.5023, -1.3365, -0.0391, -0.8349,  0.5227,  0.2080, -1.4184]],
#        grad_fn=<EmbeddingBackward0>)

# %%
# Transfomer
class MiniTransfomer(nn.Module):
    def __init__(self, embed_dim , num_heads = 2):
        super().__init__()
        self.attn = nn.MultiheadAttention(embed_dim , num_heads)
        self.ff = nn.Sequential(
            nn.Linear(embed_dim,embed_dim),
            nn.ReLU(),
            nn.Linear(embed_dim,embed_dim)
        )
        
    def forward(self, x):
        x = x.unsqueeze(1) # seq length , batch , embed_dim
        attn_out, _ = self.attn(x,x,x)
        x= attn_out + x # residual 
        x = self.ff(x)+x
        return x.squeeze(1)

model = MiniTransfomer(embed_dim)

# %%
#Training loop 
optimizer = optim.Adam(list(model.parameters())  + list(embedding.parameters()), lr= 0.01  ) 
loss_fn = nn.CrossEntropyLoss()

for epoch in range(10):
    optimizer.zero_grad()

    # recomute embeddings each epoch
    embeds = embedding(token_ids)
    inputs = embeds[:-1]
    targets = token_ids[1:]

    out = model(inputs)
    logits = out @ embedding.weight.T
    loss = loss_fn(logits,targets )

    loss.backward()
    optimizer.step()

    print(f"\n Epoch {epoch}")
    print("Transformer Output shape: ", out.shape)
    print("logits  shape: ", logits.shape)
    print("loss:", loss.item())
# Out:
#  Epoch 0
# Transformer Output shape:  torch.Size([1, 8])
# logits  shape:  torch.Size([1, 63])
# loss: 10.166955947875977
#
#  Epoch 1
# Transformer Output shape:  torch.Size([1, 8])
# logits  shape:  torch.Size([1, 63])
# loss: 8.292130470275879
#
#  Epoch 2
# Transformer Output shape:  torch.Size([1, 8])
# logits  shape:  torch.Size([1, 63])
# loss: 6.5540008544921875
#
#  Epoch 3
# Transformer Output shape:  torch.Size([1, 8])
# logits  shape:  torch.Size([1, 63])
# loss: 4.999416828155518
#
#  Epoch 4
# Transformer Output shape:  torch.Size([1, 8])
# logits  shape:  torch.Size([1, 63])
# loss: 3.6699891090393066
#
#  Epoch 5
# Transformer Output shape:  torch.Size([1, 8])
# logits  shape:  torch.Size([1, 63])
# loss: 2.584522008895874
#
#  Epoch 6
# Transformer Output shape:  torch.Size([1, 8])
# logits  shape:  torch.Size([1, 63])
# loss: 1.7058422565460205
#
#  Epoch 7
# Transformer Output shape:  torch.Size([1, 8])
# logits  shape:  torch.Size([1, 63])
# loss: 1.0221730470657349
#
#  Epoch 8
# Transformer Output shape:  torch.Size([1, 8])
# logits  shape:  torch.Size([1, 63])
# loss: 0.5475515723228455
#
#  Epoch 9
# Transformer Output shape:  torch.Size([1, 8])
# logits  shape:  torch.Size([1, 63])
# loss: 0.2675827741622925

# %%
# Visulaize

final_embeds = embedding.weight.detach().numpy()

pca = PCA(n_components=2).fit_transform(final_embeds)

plt.figure(figsize= (7,7))

for word, idx in tokenizer.get_vocab().items():
    plt.scatter(pca[idx, 0], pca[idx,1])
    plt.text(pca[idx,0]+0.01, pca[idx,1]+0.01, word)
    plt.title("Word Embeddinfs - PCA")
plt.show()
# Out:
# ) missing from font(s) DejaVu Sans.kages\IPython\core\pylabtools.py:170: UserWarning: Glyph 13 (
#   fig.canvas.print_figure(bytes_io, **kw)
